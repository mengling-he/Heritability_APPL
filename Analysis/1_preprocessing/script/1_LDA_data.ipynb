# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from sklearn.preprocessing import StandardScaler

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %% [markdown]
# This notebook is used to get LDA data of daily imputed data from both ViT and Thresholding (side and top), after deleting the dead samples.

# %%
slow_growers = Path("../data/slow_grower.txt").read_text().strip().split(",")

# %%
df_vit = pd.read_csv('../result/side_top_features_vit_linearimputed_day.csv')
df_vit = df_vit[~df_vit['Plant Info'].isin(slow_growers)]


df_threshold = pd.read_csv('../result/side_top_features_thresholding_linearimputed_day.csv')
df_threshold = df_threshold[~df_threshold['Plant Info'].isin(slow_growers)]

# %%
print(df_vit.shape, df_threshold.shape)
# Out:
# (15588, 104) (15588, 96)

# %%
print(df_vit.columns, df_threshold.columns)
# Out:
# Index(['Plant Info', 'Date', 'side_area', 'side_convex_hull_area',
#        'side_solidity', 'side_perimeter', 'side_width', 'side_height',
#        'side_longest_path', 'side_center_of_mass_x',
#        ...
#        'top_hue_max', 'top_saturation_mean', 'top_saturation_var',
#        'top_saturation_max', 'top_value_mean', 'top_value_var',
#        'top_value_min', 'top_value_max', 'Genotype', 'Replicate'],
#       dtype='object', length=104) Index(['Plant Info', 'Date', 'side_area', 'side_convex_hull_area',
#        'side_solidity', 'side_perimeter', 'side_width', 'side_height',
#        'side_longest_path', 'side_center_of_mass_x', 'side_center_of_mass_y',
#        'side_convex_hull_vertices', 'side_ellipse_center_x',
#        'side_ellipse_center_y', 'side_ellipse_major_axis',
#        'side_ellipse_minor_axis', 'side_ellipse_angle',
#        'side_ellipse_eccentricity', 'side_blue_mean', 'side_blue_var',
#        'side_blue_min', 'side_blue_max', 'side_green_mean', 'side_green_var',
#        'side_green_min', 'side_green_max', 'side_red_mean', 'side_red_var',
#        'side_red_min', 'side_red_max', 'side_lightness_mean',
#        'side_lightness_var', 'side_lightness_min', 'side_lightness_max',
#        'side_green_red_mean', 'side_green_red_var', 'side_green_red_min',
#        'side_green_red_max', 'side_blue_yellow_mean', 'side_blue_yellow_var',
#        'side_blue_yellow_min', 'side_blue_yellow_max', 'side_hue_mean',
#        'side_hue_var', 'side_hue_max', 'side_saturation_mean',
#        'side_saturation_var', 'side_saturation_max', 'side_value_mean',
#        'side_value_var', 'side_value_min', 'side_value_max', 'top_area',
#        'top_convex_hull_area', 'top_solidity', 'top_perimeter',
#        'top_longest_path', 'top_center_of_mass_x', 'top_center_of_mass_y',
#        'top_convex_hull_vertices', 'top_ellipse_center_x',
#        'top_ellipse_center_y', 'top_ellipse_major_axis',
#        'top_ellipse_minor_axis', 'top_ellipse_angle',
#        'top_ellipse_eccentricity', 'top_minarea_rect_height',
#        'top_minarea_rect_width', 'top_blue_mean', 'top_blue_var',
#        'top_blue_max', 'top_green_mean', 'top_green_var', 'top_green_max',
#        'top_red_mean', 'top_red_var', 'top_red_max', 'top_lightness_mean',
#        'top_lightness_var', 'top_lightness_max', 'top_green_red_mean',
#        'top_green_red_var', 'top_green_red_min', 'top_green_red_max',
#        'top_blue_yellow_mean', 'top_blue_yellow_var', 'top_blue_yellow_max',
#        'top_hue_mean', 'top_hue_var', 'top_saturation_mean',
#        'top_saturation_var', 'top_value_mean', 'top_value_var',
#        'top_value_max', 'Genotype', 'Replicate'],
#       dtype='object')

# %%
metric_cols_vit = [col for col in df_vit.columns if col not in ['Plant Info','Date', 'Genotype','Replicate']]
metric_cols_threshold = [col for col in df_threshold.columns if col not in ['Plant Info','Date', 'Genotype','Replicate']]

# %% [markdown]
# ### ViT

# %%
y_vit = df_vit['Genotype']

# %%
metric_cols_vit_side = [col for col in metric_cols_vit if 'side' in col]
metric_cols_vit_top = [col for col in metric_cols_vit if 'top' in col]
print(len(metric_cols_vit_side), len(metric_cols_vit_top),len(metric_cols_vit))
# Out:
# 50 50 100

# %%
# Scale features
X_vit = df_vit[metric_cols_vit]

scaler = StandardScaler()
X_vit_scaled = scaler.fit_transform(X_vit)


# Run LDA
lda = LinearDiscriminantAnalysis()
X_lda_vit = lda.fit_transform(X_vit_scaled, y_vit)

# %%
X_lda_vit
# Out:
# array([[ 0.11114098, -1.27642939,  0.94964383, ...,  0.68943922,
#         -0.77998201, -0.14942455],
#        [ 0.11114098, -1.27642939,  0.94964383, ...,  0.68943922,
#         -0.77998201, -0.14942455],
#        [ 0.15682442, -1.24801157,  0.84524372, ...,  0.49728282,
#         -0.82696591, -0.00945259],
#        ...,
#        [ 1.0032638 ,  0.6248521 ,  0.26817769, ...,  1.46593005,
#          0.37290832, -1.72060214],
#        [ 1.0032638 ,  0.6248521 ,  0.26817769, ...,  1.46593005,
#          0.37290832, -1.72060214],
#        [ 1.0032638 ,  0.6248521 ,  0.26817769, ...,  1.46593005,
#          0.37290832, -1.72060214]])

# %%
X_vit_scaled.shape
# Out:
# (15588, 100)

# %%
n_components = lda.scalings_.shape[1]
ld_names = [f"LD{i+1}" for i in range(n_components)]

loadings = pd.DataFrame(
    lda.scalings_,
    index=metric_cols_vit,
    columns=ld_names
)
# Out:
# (100, 59)

# %%
print(loadings.head)
# Out:
# <bound method NDFrame.head of                                 LD1           LD2           LD3           LD4  \
# side_area              1.516137e+00  1.353104e-01 -1.555387e-01 -3.988216e-01
# side_convex_hull_area  2.954174e-01 -7.524865e-01  2.001419e-01  1.603881e+00
# side_solidity          3.896261e-01  3.456757e-01 -4.296772e-01 -2.540946e-01
# side_perimeter        -2.291959e-01 -4.723562e-01  9.424469e-02 -6.264710e-01
# side_width             2.700787e-01  9.014515e-02 -7.079006e-02 -1.811999e-01
# ...                             ...           ...           ...           ...
# top_saturation_max    -9.390496e-15  7.316686e-15 -1.195439e-14 -9.534590e-16
# top_value_mean         1.691958e+00  1.345686e+00  1.826420e+00 -6.276589e-01
# top_value_var          8.639795e-03 -5.390625e-02  2.886505e-02  3.240206e-02
# top_value_min         -1.023184e-01  7.637017e-02 -1.972447e-02  4.732046e-02
# top_value_max         -3.336747e-01 -6.440465e-01 -1.073885e+00 -6.262377e-01
#
#                                 LD5           LD6           LD7           LD8  \
# side_area              5.908287e-01  1.591014e-01  5.278118e-01 -1.365100e-01
# side_convex_hull_area -1.063031e+00 -5.807944e-01  1.063962e-01  1.406110e-01
# side_solidity          3.571454e-01  2.667416e-01  3.114745e-01 -1.043410e+00
# side_perimeter         7.175886e-01  6.503818e-01  1.596347e-01 -5.231533e-01
# side_width             4.101482e-01  2.936385e-01 -1.901803e-01 -3.060392e-01
# ...                             ...           ...           ...           ...
# top_saturation_max    -2.626775e-15  2.302327e-14 -4.837961e-14 -4.759883e-14
# top_value_mean         3.420474e+00  1.167211e+00  3.943213e+00  1.082808e+00
# top_value_var         -4.759302e-03 -4.052447e-02 -5.825887e-02 -5.992346e-02
# top_value_min         -1.226266e-02 -3.186518e-02 -1.639143e-01 -1.376355e-01
# top_value_max         -2.432827e+00  6.819578e-01 -1.093704e+00  2.691767e+00
#
#                                 LD9          LD10  ...          LD50  \
# side_area             -4.051946e-01  2.149956e-01  ... -3.793440e-01
# side_convex_hull_area -9.423402e-02 -4.584749e-01  ... -4.147206e-01
# side_solidity         -1.928045e-01 -7.995111e-02  ...  1.905986e-02
# side_perimeter         4.439138e-01  2.338132e-01  ... -5.478091e-01
# side_width            -6.182907e-02 -3.328610e-01  ...  3.432602e-01
# ...                             ...           ...  ...           ...
# top_saturation_max    -6.672312e-14  2.421781e-14  ... -1.468843e-14
# top_value_mean         4.414739e+00 -4.105091e+00  ...  1.591940e-01
# top_value_var          6.779038e-02  3.193016e-02  ...  2.063907e-02
# top_value_min         -8.452618e-02 -1.048569e-01  ... -1.611683e-01
# top_value_max         -9.025683e-01 -7.265128e-01  ... -2.665446e+00
#
#                                LD51          LD52          LD53          LD54  \
# side_area             -4.524246e-01  4.193291e-01  2.053600e-02  3.445525e-01
# side_convex_hull_area  2.198532e-03  1.047871e+00  1.032907e+00 -1.401891e+00
# side_solidity          6.702724e-02 -1.083353e-01  8.402249e-02 -1.768996e-01
# side_perimeter         5.339303e-01 -4.392891e-01 -9.296391e-02 -2.982015e-01
# side_width            -5.497733e-01 -1.267907e-01  4.154618e-01  4.354798e-01
# ...                             ...           ...           ...           ...
# top_saturation_max     2.888029e-14  1.512427e-14 -6.732554e-15  1.232018e-14
# top_value_mean        -2.327142e+00 -1.354762e+00  3.180248e+00 -1.172663e+00
# top_value_var          7.660433e-02 -6.147795e-03  1.090856e-01 -4.685031e-02
# top_value_min          1.835192e-01 -1.296113e-01 -1.029255e-01  4.171254e-01
# top_value_max         -1.240977e+00  6.271495e+00  9.736851e-01 -1.288485e+00
#
#                                LD55          LD56          LD57          LD58  \
# side_area             -3.785102e-01  1.194984e-01 -1.852004e-01 -5.568721e-01
# side_convex_hull_area  5.952052e-02  1.159682e+00  1.221664e-01 -2.198375e-01
# side_solidity         -5.785132e-02  1.002184e-01  2.694029e-01  4.380962e-01
# side_perimeter        -5.422982e-01 -3.312941e-01  7.626481e-01  3.962937e-01
# side_width             2.151830e-01  2.942767e-01  2.572626e-01 -7.906497e-02
# ...                             ...           ...           ...           ...
# top_saturation_max     8.793929e-15  3.992247e-14  6.560110e-14  6.834668e-14
# top_value_mean         7.078121e-02  1.376353e+00  3.980498e-01  8.163919e-01
# top_value_var         -1.578376e-01 -1.660036e-01  1.167124e-01 -1.466644e-01
# top_value_min          6.598641e-02  9.065874e-02  6.471835e-01 -3.645346e-01
# top_value_max          5.356668e+00  3.397572e+00  1.582329e+00  3.651712e+00
#
#                                LD59
# side_area             -3.005457e-01
# side_convex_hull_area -1.429601e-01
# side_solidity          2.539212e-01
# side_perimeter         2.488261e-01
# side_width             2.460264e-02
# ...                             ...
# top_saturation_max     2.098833e-14
# top_value_mean        -5.312300e+00
# top_value_var         -5.105478e-02
# top_value_min          1.270333e-02
# top_value_max         -5.599622e-01
#
# [100 rows x 59 columns]>

# %%
loadings.loc['top_blue_min']
# Out:
# LD1     5.496523e-14
# LD2     1.387508e-13
# LD3    -9.500614e-14
# LD4     1.208720e-13
# LD5    -2.053345e-13
# LD6    -1.035488e-13
# LD7     4.257183e-13
# LD8     5.528912e-13
# LD9     6.250290e-13
# LD10   -2.050546e-13
# LD11    4.509047e-13
# LD12    1.098471e-12
# LD13   -5.712412e-13
# LD14   -3.346091e-13
# LD15    6.010263e-13
# LD16   -5.119395e-14
# LD17   -8.543848e-13
# LD18   -4.753688e-13
# LD19    2.407131e-13
# LD20    1.906018e-13
# LD21   -4.973235e-14
# LD22   -8.343391e-14
# LD23   -4.783458e-13
# LD24   -3.677798e-13
# LD25   -4.081869e-13
# LD26   -1.170514e-12
# LD27    3.027611e-13
# LD28    8.400502e-14
# LD29   -3.606406e-13
# LD30   -6.515215e-13
# LD31    4.222615e-13
# LD32   -5.302224e-13
# LD33   -2.649848e-13
# LD34    6.188125e-13
# LD35    1.447053e-13
# LD36   -4.867004e-14
# LD37   -1.744448e-13
# LD38    1.127288e-14
# LD39    3.409503e-13
# LD40    2.297048e-13
# LD41    1.069563e-13
# LD42   -2.049787e-13
# LD43    5.735244e-13
# LD44    3.202596e-13
# LD45   -2.189586e-13
# LD46   -4.057244e-14
# LD47   -2.408956e-13
# LD48   -3.708721e-13
# LD49   -3.845404e-13
# LD50    6.041590e-14
# LD51   -3.825055e-13
# LD52   -2.803484e-13
# LD53    2.508440e-13
# LD54   -2.840956e-13
# LD55   -5.644677e-14
# LD56   -4.937598e-13
# LD57   -6.586730e-13
# LD58   -9.643493e-13
# LD59   -2.972658e-13
# Name: top_blue_min, dtype: float64

# %%
loadings.loc['top_saturation_max']
# Out:
# LD1    -9.390496e-15
# LD2     7.316686e-15
# LD3    -1.195439e-14
# LD4    -9.534590e-16
# LD5    -2.626775e-15
# LD6     2.302327e-14
# LD7    -4.837961e-14
# LD8    -4.759883e-14
# LD9    -6.672312e-14
# LD10    2.421781e-14
# LD11   -4.179643e-14
# LD12   -7.159649e-14
# LD13    2.647955e-14
# LD14    2.983620e-14
# LD15   -4.734986e-14
# LD16    2.068549e-14
# LD17    4.925493e-14
# LD18    2.278738e-14
# LD19    1.654703e-14
# LD20   -1.508907e-14
# LD21   -4.071043e-14
# LD22    1.650468e-14
# LD23    1.606805e-14
# LD24    2.773335e-14
# LD25    3.968096e-14
# LD26    9.055766e-14
# LD27   -3.196450e-14
# LD28   -7.207461e-15
# LD29    3.385992e-14
# LD30    3.318550e-14
# LD31   -3.950663e-14
# LD32    3.925494e-14
# LD33    2.003324e-14
# LD34   -4.480440e-14
# LD35   -2.600465e-14
# LD36    6.208300e-15
# LD37    6.867085e-16
# LD38   -8.124083e-15
# LD39   -3.655754e-14
# LD40   -2.282342e-14
# LD41    6.925427e-15
# LD42    1.175781e-15
# LD43   -2.956298e-14
# LD44   -3.711427e-14
# LD45    2.447350e-14
# LD46    5.209710e-15
# LD47    2.876437e-14
# LD48    2.505037e-14
# LD49    1.999354e-14
# LD50   -1.468843e-14
# LD51    2.888029e-14
# LD52    1.512427e-14
# LD53   -6.732554e-15
# LD54    1.232018e-14
# LD55    8.793929e-15
# LD56    3.992247e-14
# LD57    6.560110e-14
# LD58    6.834668e-14
# LD59    2.098833e-14
# Name: top_saturation_max, dtype: float64

# %%
# variance of each trait column
var_series = X_vit.var()

zero_var_traits = var_series[var_series == 0].index.tolist()
print("Zero-variance traits:", zero_var_traits)
# Out:
# Zero-variance traits: ['top_blue_min', 'top_saturation_max']

# %%
var_series[var_series == 0]
# Out:
# top_blue_min          0.0
# top_saturation_max    0.0
# dtype: float64

# %%
# variance of each trait column
var_series = X_scaled_vit.var()

zero_var_traits = var_series[var_series == 0].index.tolist()
print("Zero-variance traits:", zero_var_traits)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 4
#       1 # variance of each trait column
#       2 var_series = X_scaled_vit.var()
# ----> 4 zero_var_traits = var_series[var_series == 0].index.tolist()
#       5 print("Zero-variance traits:", zero_var_traits)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'index'

# %%
X_sub_lda.shape
# Out:
# (15588, 2)

# %%
df_lda_sub = pd.DataFrame({
    "LD1": X_sub_lda[:,0],
    "LD2": X_sub_lda[:,1],
    "Genotype": y,
    "Day": features_df['Day'],
    "Replicate": features_df['Replicate']
})
